# %%
import requests

# %%
api_key = "eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzUxMiIsImtpZCI6IjI4YTMxOGY3LTAwMDAtYTFlYi03ZmExLTJjNzQzM2M2Y2NhNSJ9..yqwr4OoQ4YvQu7IPIL2YY05ll1xYq4SoQoM_ySDRLJKrZcvI9JgAqOEenHjxiK3FsYXpsbxUkMgjzbRi4pQMng"
base_url = "https://api.clashroyale.com/v1/"
headers = {"Accept":"application/json", "authorization":f"Bearer {api_key}"}

# %%
filtro = "players/%238R9U9PJCR/upcomingchests"

r=requests.get(base_url+filtro, headers=headers) # params = {"limit":20}
                                                 # print(json.dumps(r.json(), indent = 2))
eval(r.text)
# Out:
# {'items': [{'index': 0, 'name': 'Silver Chest'},
#   {'index': 1, 'name': 'Tower Troop Chest'},
#   {'index': 2, 'name': 'Silver Chest'},
#   {'index': 3, 'name': 'Silver Chest'},
#   {'index': 4, 'name': 'Golden Chest'},
#   {'index': 5, 'name': 'Silver Chest'},
#   {'index': 6, 'name': 'Golden Chest'},
#   {'index': 7, 'name': 'Silver Chest'},
#   {'index': 8, 'name': 'Silver Chest'},
#   {'index': 20, 'name': 'Giant Chest'},
#   {'index': 68, 'name': 'Mega Lightning Chest'},
#   {'index': 70, 'name': 'Magical Chest'},
#   {'index': 201, 'name': 'Epic Chest'},
#   {'index': 293, 'name': 'Legendary Chest'}]}

# %%
filtro = "cards"

r=requests.get(base_url+filtro, headers=headers) # params = {"limit":20}
                                                 # print(json.dumps(r.json(), indent = 2))
eval(r.text)
# Out:
# {'items': [{'name': 'Knight',
#    'id': 26000000,
#    'maxLevel': 14,
#    'maxEvolutionLevel': 1,
#    'elixirCost': 3,
#    'iconUrls': {'medium': 'https://api-assets.clashroyale.com/cards/300/jAj1Q5rclXxU9kVImGqSJxa4wEMfEhvwNQ_4jiGUuqg.png',
#     'evolutionMedium': 'https://api-assets.clashroyale.com/cardevolutions/300/jAj1Q5rclXxU9kVImGqSJxa4wEMfEhvwNQ_4jiGUuqg.png'},
#    'rarity': 'common'},
#   {'name': 'Archers',
#    'id': 26000001,
#    'maxLevel': 14,
#    'maxEvolutionLevel': 1,
#    'elixirCost': 3,
#    'iconUrls': {'medium': 'https://api-assets.clashroyale.com/cards/300/W4Hmp8MTSdXANN8KdblbtHwtsbt0o749BbxNqmJYfA8.png',
#     'evolutionMedium': 'https://api-assets.clashroyale.com/cardevolutions/300/W4Hmp8MTSdXANN8KdblbtHwtsbt0o749BbxNqmJYfA8.png'},
#    'rarity': 'common'},
#   {'name': 'Goblins',
#    'id': 26000002,
#    'maxLevel': 14,
#    'elixirCost': 2,
# ...

# %%
display('https://api-assets.clashroyale.com/cards/300/2GKMkBrArZXgQxf2ygFjDs4VvGYPbx8F6Lj_68iVhIM.png')
# Out:
# 'https://api-assets.clashroyale.com/cards/300/2GKMkBrArZXgQxf2ygFjDs4VvGYPbx8F6Lj_68iVhIM.png'

# %%
import json
import pymongo
from pymongo import MongoClient

# %%
# Configurações do MongoDB
MONGO_URI = 'mongodb://localhost:27017'
DATABASE_NAME = 'clash_royale'
COLLECTION_NAME = 'players'

# Função para obter dados de um jogador
def get_player_data(player_tag):
    url = f'{base_url}/players/%23{player_tag}'
    response = requests.get(url, headers=headers)
    if response.status_code == 200:
        return response.json()
    else:
        print(f'Erro ao buscar dados do jogador: {response.status_code}')
        return None

# Função para armazenar dados no MongoDB
def store_player_data(player_data):
    client = MongoClient(MONGO_URI)
    db = client[DATABASE_NAME]
    collection = db[COLLECTION_NAME]
    collection.insert_one(player_data)
    client.close()

# Função principal
def main():
    player_tag = 'YOUR_PLAYER_TAG'  # Substitua pelo tag do jogador que você deseja buscar
    player_data = get_player_data(player_tag)
    if player_data:
        store_player_data(player_data)
        print('Dados do jogador armazenados com sucesso!')
    else:
        print('Nenhum dado para armazenar.')

if __name__ == '__main__':
    main()
# Out:
# Erro ao buscar dados do jogador: 404
# Nenhum dado para armazenar.

# %% [markdown]
# ### Explicação do Código
#
# 1. **Configurações da API do Clash Royale**: Configure a URL base da API e o cabeçalho de autorização usando sua chave de API.
# 2. **Configurações do MongoDB**: Defina a URI do MongoDB e o nome do banco de dados e da coleção.
# 3. **Função `get_player_data`**: Faz uma solicitação GET à API do Clash Royale para obter dados de um jogador.
# 4. **Função `store_player_data`**: Conecta-se ao MongoDB e insere os dados do jogador na coleção especificada.
# 5. **Função `main`**: Obtém os dados do jogador usando o tag do jogador e armazena esses dados no MongoDB.
